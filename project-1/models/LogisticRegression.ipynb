# %%
import pandas as pd
from sklearn.externals import joblib
from sklearn.preprocessing import LabelEncoder
import numpy as np

x = np.load("data.npy")
y = np.load("label.npy")

from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold

kf = StratifiedKFold(n_splits=3, random_state=None, shuffle=False)

avg_list = list()
idx = 0
for train_index, test_index in kf.split(x, y):
    print (idx)
    train = x[train_index, :]
    trainLabel = y[train_index]
    test = x[test_index, :]
    testLabel = y[test_index]
    
    logisticRegression = LogisticRegression(solver='lbfgs', C = 0.1)
    logisticRegression.fit(train, trainLabel) 
    preTrainLabel = logisticRegression.predict(train)
    
    print ("Train")
    print (confusion_matrix(trainLabel, preTrainLabel))
    
    preTestLabel = logisticRegression.predict(test)
    
    print ("Test")
    print (confusion_matrix(testLabel, preTestLabel))
    
    testProb = logisticRegression.predict_proba(test)
    testProb = testProb[:, 1]
    
    fpr, tpr, thresholds = metrics.roc_curve(testLabel, testProb, pos_label=1)
    plt.figure()
    plt.plot(fpr, tpr)
    plt.show()
    print (roc_auc_score(testLabel, testProb))
    avg_list.append(roc_auc_score(testLabel, testProb))
    
    idx += 1
print (np.mean(avg_list))
# Out:
# 0
# Train
# [[   439  16660]
#  [   167 220179]]
# Test
# [[  2656   5894]
#  [  9838 100335]]
# 0.6920647182052809
# 1
# Train
# [[   176  16923]
#  [   358 219988]]
# Test
# [[   104   8446]
#  [    56 110117]]
# 0.6068595945037637
# 2
# Train
# [[   226  16874]
#  [   297 220049]]
# Test
# [[     0   8549]
#  [     0 110173]]
# 0.69385271938944
# 0.6642590106994949

# %%
avg_list = list()
idx = 0
for train_index, test_index in kf.split(x, y):
    print (idx)
    train = x[train_index, :]
    trainLabel = y[train_index]
    test = x[test_index, :]
    testLabel = y[test_index]
    
    logisticRegression = LogisticRegression(solver='lbfgs', C = 1)
    logisticRegression.fit(train, trainLabel) 
    preTrainLabel = logisticRegression.predict(train)
    
    print ("Train")
    print (confusion_matrix(trainLabel, preTrainLabel))
    
    preTestLabel = logisticRegression.predict(test)
    
    print ("Test")
    print (confusion_matrix(testLabel, preTestLabel))
    
    testProb = logisticRegression.predict_proba(test)
    testProb = testProb[:, 1]
    
    fpr, tpr, thresholds = metrics.roc_curve(testLabel, testProb, pos_label=1)
    plt.figure()
    plt.plot(fpr, tpr)
    plt.show()
    print (roc_auc_score(testLabel, testProb))
    avg_list.append(roc_auc_score(testLabel, testProb))
    
    idx += 1
print (np.mean(avg_list))
# Out:
# 0
# Train
# [[   439  16660]
#  [   167 220179]]
# Test
# [[  2656   5894]
#  [  9838 100335]]
# 0.6920647182052809
# 1
# Train
# [[   176  16923]
#  [   358 219988]]
# Test
# [[   104   8446]
#  [    56 110117]]
# 0.6068595807030336
# 2
# Train
# [[   218  16882]
#  [   267 220079]]
# Test
# [[     0   8549]
#  [     0 110173]]
# 0.6939255936444333
# 0.6642832975175826

# %%
avg_list = list()
idx = 0
for train_index, test_index in kf.split(x, y):
    print (idx)
    train = x[train_index, :]
    trainLabel = y[train_index]
    test = x[test_index, :]
    testLabel = y[test_index]
    
    logisticRegression = LogisticRegression(solver='lbfgs', C = 10)
    logisticRegression.fit(train, trainLabel) 
    preTrainLabel = logisticRegression.predict(train)
    
    print ("Train")
    print (confusion_matrix(trainLabel, preTrainLabel))
    
    preTestLabel = logisticRegression.predict(test)
    
    print ("Test")
    print (confusion_matrix(testLabel, preTestLabel))
    
    testProb = logisticRegression.predict_proba(test)
    testProb = testProb[:, 1]
    
    fpr, tpr, thresholds = metrics.roc_curve(testLabel, testProb, pos_label=1)
    plt.figure()
    plt.plot(fpr, tpr)
    plt.show()
    print (roc_auc_score(testLabel, testProb))
    avg_list.append(roc_auc_score(testLabel, testProb))
    
    idx += 1
print (np.mean(avg_list))
# Out:
# 0
# Train
# [[   439  16660]
#  [   167 220179]]
# Test
# [[  2656   5894]
#  [  9838 100335]]
# 0.6920647182052809
# 1
# Train
# [[   176  16923]
#  [   358 219988]]
# Test
# [[   104   8446]
#  [    56 110117]]
# 0.6068595807030336
# 2
# Train
# [[   218  16882]
#  [   274 220072]]
# Test
# [[     0   8549]
#  [     0 110173]]
# 0.6917385750141338
# 0.6635542913074828

# %%
avg_list = list()
idx = 0
for train_index, test_index in kf.split(x, y):
    print (idx)
    train = x[train_index, :]
    trainLabel = y[train_index]
    test = x[test_index, :]
    testLabel = y[test_index]
    
    logisticRegression = LogisticRegression(solver='lbfgs', C = 100)
    logisticRegression.fit(train, trainLabel) 
    preTrainLabel = logisticRegression.predict(train)
    
    print ("Train")
    print (confusion_matrix(trainLabel, preTrainLabel))
    
    preTestLabel = logisticRegression.predict(test)
    
    print ("Test")
    print (confusion_matrix(testLabel, preTestLabel))
    
    testProb = logisticRegression.predict_proba(test)
    testProb = testProb[:, 1]
    
    fpr, tpr, thresholds = metrics.roc_curve(testLabel, testProb, pos_label=1)
    plt.figure()
    plt.plot(fpr, tpr)
    plt.show()
    print (roc_auc_score(testLabel, testProb))
    avg_list.append(roc_auc_score(testLabel, testProb))
    
    idx += 1
print (np.mean(avg_list))
# Out:
# 0
# Train
# [[   439  16660]
#  [   167 220179]]
# Test
# [[  2656   5894]
#  [  9838 100335]]
# 0.6920647182052809
# 1
# Train
# [[   176  16923]
#  [   358 219988]]
# Test
# [[   104   8446]
#  [    56 110117]]
# 0.606859579641439
# 2
# Train
# [[   214  16886]
#  [   269 220077]]
# Test
# [[     0   8549]
#  [     0 110173]]
# 0.6944935994000788
# 0.6644726324155995

# %%
avg_list = list()
idx = 0
for train_index, test_index in kf.split(x, y):
    print (idx)
    train = x[train_index, :]
    trainLabel = y[train_index]
    test = x[test_index, :]
    testLabel = y[test_index]
    
    logisticRegression = LogisticRegression(solver='lbfgs', C = 10, class_weight='balanced')
    logisticRegression.fit(train, trainLabel) 
    preTrainLabel = logisticRegression.predict(train)
    
    print ("Train")
    print (confusion_matrix(trainLabel, preTrainLabel))
    
    preTestLabel = logisticRegression.predict(test)
    
    print ("Test")
    print (confusion_matrix(testLabel, preTestLabel))
    
    testProb = logisticRegression.predict_proba(test)
    testProb = testProb[:, 1]
    
    fpr, tpr, thresholds = metrics.roc_curve(testLabel, testProb, pos_label=1)
    plt.figure()
    plt.plot(fpr, tpr)
    plt.show()
    print (roc_auc_score(testLabel, testProb))
    avg_list.append(roc_auc_score(testLabel, testProb))
    
    idx += 1
print (np.mean(avg_list))
# Out:
# 0
# Train
# [[ 10943   6156]
#  [ 55927 164419]]
# Test
# [[  8528     22]
#  [109252    921]]
# 0.6476335670486975
# 1
# Train
# [[  8408   8691]
#  [ 65141 155205]]
# Test
# [[ 3847  4703]
#  [21242 88931]]
# 0.7004479239269786
# 2
# Train
# [[ 11037   6063]
#  [ 83065 137281]]
# Test
# [[   652   7897]
#  [  1549 108624]]
# 0.7194509603218411
# 0.6891774837658392

# %%
avg_list = list()
idx = 0
for train_index, test_index in kf.split(x, y):
    print (idx)
    train = x[train_index, :]
    trainLabel = y[train_index]
    test = x[test_index, :]
    testLabel = y[test_index]
    
    logisticRegression = LogisticRegression(solver='lbfgs', C = 100, class_weight='balanced')
    logisticRegression.fit(train, trainLabel) 
    preTrainLabel = logisticRegression.predict(train)
    
    print ("Train")
    print (confusion_matrix(trainLabel, preTrainLabel))
    
    preTestLabel = logisticRegression.predict(test)
    
    print ("Test")
    print (confusion_matrix(testLabel, preTestLabel))
    
    testProb = logisticRegression.predict_proba(test)
    testProb = testProb[:, 1]
    
    fpr, tpr, thresholds = metrics.roc_curve(testLabel, testProb, pos_label=1)
    plt.figure()
    plt.plot(fpr, tpr)
    plt.show()
    print (roc_auc_score(testLabel, testProb))
    avg_list.append(roc_auc_score(testLabel, testProb))
    
    idx += 1
print (np.mean(avg_list))
# Out:
# 0
# Train
# [[ 10943   6156]
#  [ 55927 164419]]
# Test
# [[  8528     22]
#  [109252    921]]
# 0.6476335628023189
# 1
# Train
# [[  8411   8688]
#  [ 65178 155168]]
# Test
# [[ 3848  4702]
#  [21249 88924]]
# 0.7004554071074716
# 2
# Train
# [[ 11037   6063]
#  [ 83065 137281]]
# Test
# [[   652   7897]
#  [  1549 108624]]
# 0.7194509603218411
# 0.6891799767438771

# %%
avg_list = list()
idx = 0
for train_index, test_index in kf.split(x, y):
    print (idx)
    train = x[train_index, :]
    trainLabel = y[train_index]
    test = x[test_index, :]
    testLabel = y[test_index]
    
    logisticRegression = LogisticRegression(solver='lbfgs', C = 1, class_weight='balanced')
    logisticRegression.fit(train, trainLabel) 
    preTrainLabel = logisticRegression.predict(train)
    
    print ("Train")
    print (confusion_matrix(trainLabel, preTrainLabel))
    
    preTestLabel = logisticRegression.predict(test)
    
    print ("Test")
    print (confusion_matrix(testLabel, preTestLabel))
    
    testProb = logisticRegression.predict_proba(test)
    testProb = testProb[:, 1]
    
    fpr, tpr, thresholds = metrics.roc_curve(testLabel, testProb, pos_label=1)
    plt.figure()
    plt.plot(fpr, tpr)
    plt.show()
    print (roc_auc_score(testLabel, testProb))
    avg_list.append(roc_auc_score(testLabel, testProb))
    
    idx += 1
print (np.mean(avg_list))
# Out:
# 0
# Train
# [[ 10943   6156]
#  [ 55927 164419]]
# Test
# [[  8528     22]
#  [109252    921]]
# 0.6476335649255082
# 1
# Train
# [[  8411   8688]
#  [ 65169 155177]]
# Test
# [[ 3848  4702]
#  [21245 88928]]
# 0.7004530312587067
# 2
# Train
# [[ 11037   6063]
#  [ 83065 137281]]
# Test
# [[   652   7897]
#  [  1549 108624]]
# 0.7194509603218411
# 0.6891791855020187
